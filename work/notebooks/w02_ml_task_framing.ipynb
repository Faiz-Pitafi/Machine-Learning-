# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Faiz-Pitafi/Machine-Learning-/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# 1. My Lane as an ML Task (Type)

#**Task Type:** Classification

#My chosen lane is Machine Learning. I selected **classification** because the goal is to predict a category or class based on input data. Classification models learn patterns from labeled data and assign new observations to one of the predefined classes.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# 2. Target or Proxy

#The target variable is the **recipe type**, which has two classes:

#- Cupcake
#- Muffin

#The labels come from the observed recipe category in the dataset. The model will learn from these labeled examples to classify new recipes.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# 3. Success Metric

#The primary success metric is **Accuracy** because this is a binary classification problem.

#A model with an accuracy above **90%** would be considered a strong starting point. I would also check precision, recall, and the F1-score to ensure the model performs well on both classes.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_excel("/content/Cupcake and muffins data set recipes.xlsx")

print(df.head())
print(df.columns)
# Out:
#       Type  Flour  sugar  salt  milk  butter  eggs  baking powder  Toppings
# 0  cupcake     30     45     1    34      20    32              2         2
# 1  cupcake     31     44     1    35      22    30              2         2
# 2  cupcake     31     43     1    40      24    30              2         2
# 3  cupcake     33     37     1    39      21    31              2         2
# 4  cupcake     36     39     1    37      23    33              2         2
# Index(['Type', 'Flour', 'sugar', 'salt', 'milk', 'butter', 'eggs',
#        'baking powder', 'Toppings'],
#       dtype='object')

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# 5. Why ML Beats a Fixed Rule

#A fixed rule such as "if sugar > 40 then cupcake" is not reliable because recipes use different combinations of ingredients. A cupcake and a muffin may have similar amounts of flour or sugar but differ in several ingredients at the same time.

#A machine learning model can learn complex relationships between multiple ingredients and make better predictions than a simple if–else rule. This makes the model more accurate and adaptable to new recipes.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
