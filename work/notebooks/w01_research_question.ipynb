# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Faiz-Pitafi/Machine-Learning-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#Predict sales
#I chose the Predict Sales lane because businesses need to estimate future sales to make better decisions about inventory, staffing, budgeting, and marketing. Accurate sales predictions help improve planning and reduce waste.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#ecide how much inventory or stock should be prepared for the upcoming period.
#Managers can order the right amount of products, schedule staff appropriately, and plan marketing campaigns based on the predicted sales.
#If sales are overestimated:

#"""Too much inventory is purchased.
#Storage costs increase.
#Products may remain unsold.

#If sales are underestimated:

#Products run out of stock.
#Customers cannot buy what they want.
#The business loses revenue and customer trust#"""#

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("/content/statsfinal.csv")

print(df.shape)
print(df["Q-P1"].describe())
print(df.head())
# Out:
# (4600, 10)
# count    4600.000000
# mean     4121.849130
# std      2244.271323
# min       254.000000
# 25%      2150.500000
# 50%      4137.000000
# 75%      6072.000000
# max      7998.000000
# Name: Q-P1, dtype: float64
#    Unnamed: 0        Date  Q-P1  Q-P2  Q-P3  Q-P4      S-P1      S-P2  \
# 0           0  13-06-2010  5422  3725   576   907  17187.74  23616.50
# 1           1  14-06-2010  7047   779  3578  1574  22338.99   4938.86
# 2           2  15-06-2010  1572  2082   595  1145   4983.24  13199.88
# 3           3  16-06-2010  5657  2399  3140  1672  17932.69  15209.66
# 4           4  17-06-2010  3668  3207  2184   708  11627.56  20332.38
#
#        S-P3      S-P4
# 0   3121.92   6466.91
# 1  19392.76  11222.62
# 2   3224.90   8163.85
# 3  17018.80  11921.36
# 4  11837.28   5048.04

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#This project aims to predict sales based on historical data and available features. The model can identify patterns in the data, but it cannot prove that any feature directly causes changes in sales. Predictions will depend on the quality and completeness of the available data

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
